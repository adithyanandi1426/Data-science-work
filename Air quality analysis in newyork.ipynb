# %%
import pandas as pd
import numpy as np

# %%
url = "https://data.cityofnewyork.us/api/views/c3uy-2p5r/rows.csv"

# %%
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       16122 non-null  int64
#  1   Indicator ID    16122 non-null  int64
#  2   Name            16122 non-null  object
#  3   Measure         16122 non-null  object
#  4   Measure Info    16122 non-null  object
#  5   Geo Type Name   16122 non-null  object
#  6   Geo Join ID     16122 non-null  int64
#  7   Geo Place Name  16122 non-null  object
#  8   Time Period     16122 non-null  object
#  9   Start_Date      16122 non-null  object
#  10  Data Value      16122 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unique ID</th>
#       <th>Indicator ID</th>
#       <th>Geo Join ID</th>
#       <th>Data Value</th>
#       <th>Message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>16122.000000</td>
#       <td>16122.000000</td>
#       <td>1.612200e+04</td>
#       <td>16122.000000</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>339480.955589</td>
#       <td>427.131063</td>
#       <td>6.133394e+05</td>
#       <td>19.129163</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>194099.809551</td>
# ...

# %%
df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unique ID</th>
#       <th>Indicator ID</th>
#       <th>Name</th>
#       <th>Measure</th>
#       <th>Measure Info</th>
#       <th>Geo Type Name</th>
#       <th>Geo Join ID</th>
#       <th>Geo Place Name</th>
#       <th>Time Period</th>
#       <th>Start_Date</th>
#       <th>Data Value</th>
#       <th>Message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>216498</td>
#       <td>386</td>
#       <td>Ozone (O3)</td>
#       <td>Mean</td>
#       <td>ppb</td>
#       <td>CD</td>
#       <td>313</td>
#       <td>Coney Island (CD13)</td>
#       <td>Summer 2013</td>
# ...

# %%
df['Message'].unique()
# Out:
# Out[7]: array([nan])

# %%
df_1  =df.drop(['Message'],axis=1)

# %%
df.columns
# Out:
# Out[9]: Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value', 'Message'],
#       dtype='object')

# %%
df_1.columns
# Out:
# Out[10]: Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value'],
#       dtype='object')

# %%
df['Geo Place Name']
# Out:
# Out[11]: 0                           Coney Island (CD13)
# 1                           Coney Island (CD13)
# 2                                         Bronx
# 3                                         Bronx
# 4              Morris Park and Bronxdale (CD11)
#                           ...
# 16117      Park Slope and Carroll Gardens (CD6)
# 16118     East New York and Starrett City (CD5)
# 16119                            Bushwick (CD4)
# 16120                  Bedford Stuyvesant (CD3)
# 16121    Fort Greene and Brooklyn Heights (CD2)
# Name: Geo Place Name, Length: 16122, dtype: object

# %%
df_1["Time Period"].unique
# Out:
# Out[12]: <bound method Series.unique of 0           Summer 2013
# 1           Summer 2014
# 2           Summer 2013
# 3           Summer 2014
# 4        Winter 2008-09
#               ...
# 16117       Summer 2020
# 16118       Summer 2020
# 16119       Summer 2020
# 16120       Summer 2020
# 16121       Summer 2020
# Name: Time Period, Length: 16122, dtype: object>

# %%
df_1["Start_Date"].value_counts()
# Out:
# Out[14]: 01/01/2015    906
# 01/01/2005    887
# 12/01/2011    705
# 12/01/2008    705
# 12/01/2009    705
# 12/01/2010    705
# 12/01/2012    705
# 12/01/2013    705
# 01/01/2009    480
# 01/02/2012    480
# 12/01/2014    423
# 06/01/2018    423
# 05/31/2016    423
# 12/01/2015    423
# 06/01/2015    423
# 06/01/2014    423
# 06/01/2013    423
# 06/01/2019    423
# 06/01/2020    423
# 06/01/2012    423
# 06/01/2011    423
# 06/01/2010    423
# 06/01/2009    423
# 06/01/2017    423
# 01/01/2016    321
# 12/31/2015    282
# 01/01/2017    282
# 12/01/2016    282
# 01/01/2018    282
# 12/01/2017    282
# 01/01/2019    282
# 12/01/2018    282
# 01/01/2020    282
# 12/01/2019    282
# 01/01/2011    214
# 01/01/2013    144
# Name: Start_Date, dtype: int64

# %%
pd.crosstab(df["Time Period"], df["Data Value"])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Data Value</th>
#       <th>0.00</th>
#       <th>0.10</th>
#       <th>0.11</th>
#       <th>0.12</th>
#       <th>0.13</th>
#       <th>0.16</th>
#       <th>0.17</th>
#       <th>0.18</th>
#       <th>0.19</th>
#       <th>0.20</th>
#       <th>...</th>
#       <th>276.00</th>
#       <th>277.70</th>
#       <th>278.60</th>
#       <th>284.70</th>
#       <th>291.10</th>
#       <th>292.50</th>
#       <th>299.40</th>
#       <th>308.00</th>
#       <th>354.20</th>
#       <th>424.70</th>
#     </tr>
#     <tr>
#       <th>Time Period</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
pd.crosstab(df["Geo Place Name"], df["Data Value"])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Data Value</th>
#       <th>0.00</th>
#       <th>0.10</th>
#       <th>0.11</th>
#       <th>0.12</th>
#       <th>0.13</th>
#       <th>0.16</th>
#       <th>0.17</th>
#       <th>0.18</th>
#       <th>0.19</th>
#       <th>0.20</th>
#       <th>...</th>
#       <th>276.00</th>
#       <th>277.70</th>
#       <th>278.60</th>
#       <th>284.70</th>
#       <th>291.10</th>
#       <th>292.50</th>
#       <th>299.40</th>
#       <th>308.00</th>
#       <th>354.20</th>
#       <th>424.70</th>
#     </tr>
#     <tr>
#       <th>Geo Place Name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
df.pivot_table(
    ["Data Value"],
    ["Start_Date","Geo Place Name"],
    aggfunc = "max",
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Data Value</th>
#     </tr>
#     <tr>
#       <th>Start_Date</th>
#       <th>Geo Place Name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">01/01/2005</th>
#       <th>Bay Ridge and Dyker Heights (CD10)</th>
#       <td>30.80</td>
#     </tr>
#     <tr>
#       <th>Bayside - Little Neck</th>
#       <td>48.90</td>
#     </tr>
#     <tr>
#       <th>Bayside and Little Neck (CD11)</th>
#       <td>35.10</td>
#     </tr>
#     <tr>
#       <th>Bedford Stuyvesant (CD3)</th>
#       <td>26.00</td>
#     </tr>
#     <tr>
# ...

# %%
df.pivot_table(
    ["Data Value"],
    ["Start_Date","Geo Place Name"],
    aggfunc = "min",
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Data Value</th>
#     </tr>
#     <tr>
#       <th>Start_Date</th>
#       <th>Geo Place Name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">01/01/2005</th>
#       <th>Bay Ridge and Dyker Heights (CD10)</th>
#       <td>1.80</td>
#     </tr>
#     <tr>
#       <th>Bayside - Little Neck</th>
#       <td>1.80</td>
#     </tr>
#     <tr>
#       <th>Bayside and Little Neck (CD11)</th>
#       <td>2.10</td>
#     </tr>
#     <tr>
#       <th>Bedford Stuyvesant (CD3)</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
# ...

# %%
df.pivot_table(
    ["Data Value"],
    ["Start_Date","Geo Place Name"],
    aggfunc = "mean",
)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Data Value</th>
#     </tr>
#     <tr>
#       <th>Start_Date</th>
#       <th>Geo Place Name</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="5" valign="top">01/01/2005</th>
#       <th>Bay Ridge and Dyker Heights (CD10)</th>
#       <td>20.466667</td>
#     </tr>
#     <tr>
#       <th>Bayside - Little Neck</th>
#       <td>15.626667</td>
#     </tr>
#     <tr>
#       <th>Bayside and Little Neck (CD11)</th>
#       <td>23.366667</td>
#     </tr>
#     <tr>
#       <th>Bedford Stuyvesant (CD3)</th>
#       <td>17.266667</td>
#     </tr>
#     <tr>
# ...

# %%
import matplotlib.pyplot as plt

# %%
pd.plotting.scatter_matrix(
    df[["Data Value", "Geo Place Name"]],
    figsize = (15, 15),
    diagonal = "kde")
plt.show()

# %%
df["Data Value"].hist()
# Out:
# Out[37]: <AxesSubplot:>

# %%
df.boxplot(column = "Data Value",
           by = "Unique ID")
plt.show()
